# %% [markdown]
# # AppService ( WebApp )

# %% [markdown]
# Se utiliza AppService para crear una WebApp:
#     1. Nos vamos a Recursos y AppService
#     2. Configuramos todo lo necesario al respecto de nuestro recurso.
#
#    ![image.png](attachment:4319e7cc-df01-42bf-b969-6ca319474c55.png)
#
#    ![image.png](attachment:3c5c61d7-8d51-4bcd-a013-d53f1c1d2ee3.png)
#
#    ![image.png](attachment:d12caa0a-ea71-4d28-a1e2-f55d410fa7fb.png)
#
#
#    ![image.png](attachment:0638adc7-4de1-46f3-bd2a-1efd00261562.png)

# %% [markdown]
# Seleccionamos luego todo lo predeterminado de las siguientes pestañas
# En etiquetas agregamos CreatedBy, Area y Ciclo
# ![image.png](attachment:47af6eaa-4c26-4e18-866e-2659c9d1158d.png)

# %% [markdown]
# E implementamos
# ![image.png](attachment:15fa68a8-945b-40d0-83f4-601ec8be6904.png)

# %% [markdown]
# ![image.png](attachment:3efd28e2-410b-4679-9f1f-e376d869c5e8.png)
